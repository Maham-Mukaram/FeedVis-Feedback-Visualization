# %% [markdown]
# # Chat Intents
#
# ## Topic Modeling

# %% [markdown]
# **Summary**
#
# This notebook explores the possibilty of using topic modeling to extract intents from the 1,000 sample subset of the overall bank77 dataset. The scikit-learn and gensim implementations of LDA are investigated. Additionally, Correlation Explanation (https://github.com/gregversteeg/corex_topic), or CorEx, is also included in the analysis. As shown in the analysis below, one of the biggest challenges is identifying how many topics to include.
#
# In order to avoid some package dependency conflicts, this notebook was created in a separate virtual environment than the rest of the notebooks and code in this repo. Before being able to run the below notebook, install gensim, pyLDAvis, and CorEx using:
#
# `pip install gensim`
#
# `pip install pyldavis`
#
# `pip install corextopic`

# %%
# %pip install gensim

# %pip install pyldavis

# %pip install corextopic
# Out:
# Requirement already satisfied: gensim in ./.venv/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in ./.venv/lib/python3.10/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in ./.venv/lib/python3.10/site-packages (from gensim) (1.12.0)
# Requirement already satisfied: smart-open>=1.8.1 in ./.venv/lib/python3.10/site-packages (from gensim) (6.4.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyldavis in ./.venv/lib/python3.10/site-packages (3.4.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from pyldavis) (3.1.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in ./.venv/lib/python3.10/site-packages (from pyldavis) (1.4.1.post1)
# Requirement already satisfied: scipy in ./.venv/lib/python3.10/site-packages (from pyldavis) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.10/site-packages (from pyldavis) (1.3.2)
# Requirement already satisfied: numpy>=1.24.2 in ./.venv/lib/python3.10/site-packages (from pyldavis) (1.26.4)
# Requirement already satisfied: gensim in ./.venv/lib/python3.10/site-packages (from pyldavis) (4.3.2)
# Requirement already satisfied: funcy in ./.venv/lib/python3.10/site-packages (from pyldavis) (2.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.10/site-packages (from pyldavis) (59.6.0)
# Requirement already satisfied: pandas>=2.0.0 in ./.venv/lib/python3.10/site-packages (from pyldavis) (2.2.1)
# Requirement already satisfied: numexpr in ./.venv/lib/python3.10/site-packages (from pyldavis) (2.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas>=2.0.0->pyldavis) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas>=2.0.0->pyldavis) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas>=2.0.0->pyldavis) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.10/site-packages (from scikit-learn>=1.0.0->pyldavis) (3.4.0)
# Requirement already satisfied: smart-open>=1.8.1 in ./.venv/lib/python3.10/site-packages (from gensim->pyldavis) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->pyldavis) (2.1.5)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyldavis) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: corextopic in ./.venv/lib/python3.10/site-packages (1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.manifold import TSNE

import gensim
from gensim.corpora.dictionary import Dictionary
from gensim.models.phrases import Phrases, Phraser
from gensim.models import CoherenceModel
import pyLDAvis
import pyLDAvis.gensim_models
from corextopic import corextopic as ct

import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)
pd.set_option("max_colwidth", 400)

# %%
import pickle
product_asin='B018Y229OU'

with open(f'Reviews_{product_asin}.pkl', 'rb') as f:
    data_sample = pickle.load(f)

data_sample_positive=data_sample[data_sample.predef_sentiment=='positive']
data_sample_negative=data_sample[data_sample.predef_sentiment=='negative']
data_sample_neutral=data_sample[data_sample.predef_sentiment=='neutral']

# %%
X_positive = data_sample_positive['review']
X_negative = data_sample_negative['review']
X_neutral = data_sample_neutral['review']

# %%
print(X_positive, X_negative, X_neutral)
# Out:
# 0        Good basic tablet for checking email , web browsing , and reading ebooks.
# 1                                                              I love this tablet.
# 2                                                              It was a great buy.
# 3                                            I would strongly recommend buying it.
# 4                           It's a great reader but also good for surfing the web.
#                                            ...
# 27593                I have bought 3 of these tablets for my great grand children.
# 27595                     Bought this for my four year old niece and she loves it.
# 27596                          Its exactly what I am wanted and the price was fair
# 27597                                    Awesome tablet it's fast and easy to use.
# 27598                               Affordable can't find any better at this price
# Name: review, Length: 18416, dtype: object 54                                                                                                                                                   They haven't put them dwn willingly yet!
# 111                                                                                                                                            Slow to use because there are constant popups.
# 112                                                                                                                           Barely dropped it 2 feet to the ground and now it doesn't work.
# 113                                                                                                                                                                       Highly unsatisfied.
# 119                                                                                                                                            Very slow if you want to stream videos though.
#                                                                                                  ...
# 27534                                                                                                                I only wish we had things like this in the dark ages when I was a child!
# 27538                                                                                                                   The omnipresent advertising is annoying but also easy to just ignore.
# 27544    Only complaint is, you have to reconnect it to WiFi again whenever you turn it off and back on - and sometimes it won't connect to certain ones - possibly due to security settings?
# 27579                                                                                                           my daughter cant put this thing down, so it's doing what it's supposed to do.
# 27582                                                                              My granddaughter used her phone constantly to play games and when she needed to make a call phone is dead.
# Name: review, Length: 2484, dtype: object 5        Brought my old tablet in to my local store, and when they said that I would need to replace iit, they suggested this tablet.
# 11                                                                                  She is able to play games and watch videos on it.
# 12                                                                                            She does occasionally read with it too.
# 15                                                                                                          Purchased for my toddler.
# 17                                                                                                    Also added the protection plan.
#                                                                      ...
# 27577                                                                                                  was bought to use with Kindle.
# 27583                                                          Now with tablet, she FaceTime me more and her phone now keep a chatge.
# 27589                                                                                           Got it for my daughter to read books.
# 27591                                                                              I bought this tablet for my grandson in 4th grade.
# 27594                                                                                    excellent for learning and u don't use data.
# Name: review, Length: 6699, dtype: object

# %% [markdown]
# ## LDA with Scikit-learn

# %%
count_vectorizer = CountVectorizer(ngram_range = (1, 2), max_df = 900, min_df = 10)

transformed_vector = count_vectorizer.fit_transform(X)
transformed_vector.shape
# Out:
# (2484, 822)

# %%
feature_names = count_vectorizer.get_feature_names_out()
feature_names[0:10]
# Out:
# array(['10', '15', '35', '50', 'able', 'able to', 'about', 'about it',
#        'about the', 'access'], dtype=object)

# %%
# %%time

perplexities = []
for NUM_TOPICS in range(3,20):
    lda_model = LatentDirichletAllocation(n_components = NUM_TOPICS, max_iter=20)
    lda = lda_model.fit_transform(transformed_vector)
    perplexities.append(lda_model.perplexity(transformed_vector))
# Out:
# CPU times: user 2min 13s, sys: 8.14 ms, total: 2min 13s
# Wall time: 2min 13s

# %%
x = range(3, 20)
y = perplexities

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x, y)

ax.set(xlabel = 'num topics', ylabel = 'perplexity', title = 'LDA')
ax.grid()

plt.show()

# %%
# %%time

scores = []
for NUM_TOPICS in range(3,20):
    lda_model = LatentDirichletAllocation(n_components = NUM_TOPICS, max_iter=20)
    lda = lda_model.fit_transform(transformed_vector)
    scores.append(lda_model.score(transformed_vector))
# Out:
# CPU times: user 2min 15s, sys: 12.1 ms, total: 2min 15s
# Wall time: 2min 15s

# %%
x = range(3, 20)
y = scores

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x, y)

ax.set(xlabel = 'num topics', ylabel = 'score', title = 'LDA')
ax.grid()

plt.show()

# %% [markdown]
# Some literature suggests that it might be possible to use perplexity (https://en.wikipedia.org/wiki/Perplexity)  to determine an optimal number of topics, but others have questioned relying on it. Regardless, the scikit-learn implementation appears to still have a bug(https://github.com/scikit-learn/scikit-learn/issues/6777) that makes the perplexity value unreliable.

# %% [markdown]
# ### Evaluate a fixed number of topics

# %%
NUM_TOPICS = 9

lda_model = LatentDirichletAllocation(n_components = NUM_TOPICS, max_iter=20)

lda = lda_model.fit_transform(transformed_vector)
lda.shape
# Out:
# (2484, 9)

# %%
sum(lda[0])
# Out:
# 1.0

# %%
lda_model.components_.shape
# Out:
# (9, 822)

# %%
lda_model.score(transformed_vector)
# Out:
# -201512.6861664963

# %%
def print_topic(identifier, top_words=10):
    for topic_id, topic_word_probs in enumerate(lda_model.components_):
        if topic_id == identifier:
            print(f"Topic {topic_id}: ")
            
            top_feature_names = [feature_names[i] for i in topic_word_probs.argsort()[: -top_words - 1: -1]]
            
            print(" ".join(top_feature_names))

# %%
for i in range(NUM_TOPICS):
    print_topic(i, top_words=10)
# Out:
# Topic 0:
# is only as it it is and slow is the the only very
# Topic 1:
# to it have not and as does in does not ipad
# Topic 2:
# that apps is amazon on app only google store are
# Topic 3:
# to and this had with my it is amazon tablet
# Topic 4:
# of not to it of the do work at all like
# Topic 5:
# it to was be you can use and but with
# Topic 6:
# to on screen ads they you like that don have
# Topic 7:
# for was this my price tablet it and for the that
# Topic 8:
# not is this but tablet you is not for good great

# %%
topics = []

for i in range(len(X)):
    topics.append(lda[i].argmax())

# %%
data_sample['topic'] = topics

data_sample.head()
# Out:
#         product  year  \
# 54   B018Y229OU  2015
# 111  B018Y229OU  2016
# 112  B018Y229OU  2016
# 113  B018Y229OU  2016
# 119  B018Y229OU  2016
#
#                                                               review  \
# 54                          They haven't put them dwn willingly yet!
# 111                   Slow to use because there are constant popups.
# 112  Barely dropped it 2 feet to the ground and now it doesn't work.
# 113                                              Highly unsatisfied.
# 119                   Very slow if you want to stream videos though.
#
#     predef_sentiment zc_sentiment  topic
# 54          negative     negative      6
# 111         negative     negative      5
# 112         negative     negative      3
# 113         negative     negative      0
# 119         negative     negative      8

# %%
tsne = TSNE(n_components = 2, init = 'pca', random_state = 0)
lda_2d_tsne = tsne.fit_transform(lda)
lda_df_tsne = pd.DataFrame(lda_2d_tsne)
lda_df_tsne.shape
# Out:
# (2484, 2)

# %%
plt.subplots(figsize=(12, 10))
plt.axis('equal')

plt.scatter(lda_df_tsne[0], lda_df_tsne[1], c=data_sample['topic'], cmap = plt.cm.Spectral)

# %% [markdown]
# ## LDA with Gensim

# %% [markdown]
# Gensim is a popular library for performing topic modeling and provides some additional functionality compared to the scikit-learn implementation.

# %%
all_messages = data_sample['review'].values.tolist()
all_tokens = [sent.split(' ') for sent in all_messages]

# %%
# Add bigrams and trigrams to docs (only ones that appear 10 times or more).
bigram_phrases = Phrases(all_tokens, min_count=5)
bigram = Phraser(bigram_phrases)

for idx in range(len(all_tokens)):
    for token in bigram[all_tokens[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            all_tokens[idx].append(token)

# %%
bigram.phrasegrams
# Out:
# {'there_are': 15.56810035842294,
#  'if_you': 29.897295012679628,
#  'want_to': 11.101224105461393,
#  'complaint_is': 16.000383548710687,
#  'too_much': 35.26271186440678,
#  'Bought_this': 21.242342342342344,
#  'be_able': 19.207396546106224,
#  'able_to': 17.49283798436341,
#  'The_only': 32.28617886178861,
#  'only_drawback': 25.55989159891599,
#  'a_lot': 22.277966742252456,
#  'I_bought': 12.248831168831169,
#  'other_tablets.': 26.286510590858416,
#  'at_times': 28.61529126213592,
#  "I_don't": 14.175003955070402,
#  "don't_like": 43.26223567726251,
#  'bought_this': 16.736390936390936,
#  'did_not': 17.8809403437816,
#  'does_not': 24.103245591617686,
#  'google_play': 104.79555555555555,
#  'a_bit': 23.88956433637285,
#  "I_didn't": 10.655233236151602,
#  "didn't_want": 58.58136645962733,
#  'pop_up': 36.38734567901234,
#  'due_to': 15.858891579230562,
#  'too_many': 48.73708143861099,
#  "you_can't": 15.208126824631679,
#  'at_all.': 101.74325782092771,
#  'I_am': 17.376814058956917,
#  'this_tablet': 10.233940972222221,
#  'say_about': 13.283943661971831,
#  'dead_pixels': 245.61458333333331,
#  'you_can': 16.82531753960325,
#  'easy_to': 11.685499058380413,
#  'hard_time': 26.404255319148938,
#  'tablet,_but': 10.134240687679084,
#  'There_are': 38.58181393174381,
#  'some_games': 15.173101673101673,
#  'Only_problem': 20.71058410188845,
#  'stopped_working': 229.66558441558442,
#  'no_longer': 115.58333333333333,
#  'only_thing': 34.85439763488544,
#  'Only_downside': 28.47705314009662,
#  'downside_is': 15.826466336224701,
#  'slower_than': 43.66481481481482,
#  'know_how': 43.66481481481482,
#  'year_old': 175.744099378882,
#  "can't_get": 14.397630823716188,
#  'been_able': 27.48135198135198,
#  'a_little': 19.32848945525002,
#  'came_with': 20.22790963683157,
#  'Only_thing': 31.065876152832676,
#  'in_order': 66.1270032051282,
#  'use_it.': 11.754237288135592,
#  'Only_issue': 17.08623188405797,
#  'out_of': 16.118205184293995,
#  'care_for': 21.714285714285715,
#  "if_you're": 12.955494505494505,
#  'trying_to': 13.060263653483993,
#  "doesn't_have": 10.944352759154203,
#  'best_buy': 20.05017006802721,
#  'they_were': 14.035119047619048,
#  'My_only': 32.65986148750376,
#  'only_complaint': 52.032636469221835,
#  'only_negative': 15.335934959349593,
#  'difficult_to': 10.572594386153709,
#  'at_all': 16.867961165048545,
#  'bad_thing': 22.328598484848484,
#  'a_few': 18.346560846560845,
#  "I've_had": 24.63845350052247,
#  'fact_that': 13.979644268774704,
#  'these_tablets': 52.339622641509436,
#  'battery_life.': 169.02508960573476,
#  'at_times.': 68.67669902912621,
#  'my_daughter': 22.328598484848484,
#  'fan_of': 33.390134529147986,
#  'Google_Play': 218.7291280148423,
#  'compatible_with': 21.9135687732342,
#  'Best_Buy': 505.26428571428573,
#  'do_not': 12.389806088548378,
#  'charging_port': 213.38461538461542,
#  'This_tablet': 11.808393429487179,
#  'play_store': 11.148463356973995,
#  'can_be': 21.990509106868554,
#  'battery_life': 225.36678614097968,
#  'lot_of': 28.699615631005766,
#  'very_good': 10.124087591240876,
#  'you_cannot': 10.847902097902098,
#  'only_downside': 38.33983739837398,
#  'figure_out': 78.42239467849224,
#  'out_how': 31.949864498644985,
#  'would_be': 19.071414977638216,
#  'The_camera': 12.728205128205127,
#  'my_kids': 15.761363636363635,
#  'If_you': 27.48135198135198,
#  'my_son': 29.77146464646465,
#  'more_expensive': 49.64,
#  'unable_to': 14.801632140615192,
#  'an_hour': 31.949864498644985,
#  'set_up': 39.695286195286194,
#  "doesn't_work": 11.61527093596059,
#  'very_slow': 18.50639667216074,
#  'not_recommend': 11.190792596108212,
#  "Don't_like": 17.44008875739645,
#  'Only_downfall': 48.81780538302278,
#  'the_same': 10.678894927536232,
#  'more_than': 46.5758024691358,
#  'first_one': 34.681375252803825,
#  'only_problem': 13.941759053954176,
#  'only_issue': 11.501951219512195,
#  'Kindle_Fire': 50.008483563096505,
#  'have_been': 22.91766176062205,
#  'compared_to': 13.66304505287556,
#  'as_good': 10.902183406113537,
#  'lack_of': 35.24514200298954,
#  'I_thought': 12.030102040816328,
#  'Google_play': 21.38684807256236,
#  'let_you': 20.611013986013987,
#  'looking_for': 12.304761904761905,
#  'this_product.': 16.092683592683592,
#  '6_months': 120.91794871794872,
#  'little_slow': 35.70952597304255,
#  'It_has': 11.072032306536439,
#  'new_one': 14.16156156156156,
#  'ads_on': 10.73073422330097,
#  'lock_screen': 90.54336,
#  'seem_to': 10.361142498430635,
#  'Black_Friday': 561.4047619047619,
#  'ended_up': 81.87152777777777,
#  "don't_know": 20.30921619293712,
#  'drawback_is': 12.985818532286933,
#  'unless_you': 29.444305694305694,
#  'life_is': 10.821515443572444,
#  'kindle_fire': 40.82943722943723,
#  'what_you': 10.888837577516822,
#  'never_buy': 24.767857142857142,
#  'an_iPad': 25.55989159891599,
#  "wouldn't_recommend": 22.75965250965251,
#  'disappointed_by': 12.955494505494505,
#  'screen_resolution': 22.192,
#  'going_to': 10.092021914055813,
#  'app_store': 67.38996506827564,
#  'other_than': 12.656468062265164,
#  'kind_of': 33.9863869314542,
#  'no_way': 17.54389880952381,
#  'as_well': 10.296506550218341,
#  'touch_screen': 15.719333333333333,
#  'Play_store': 22.8036750483559}

# %%
dictionary = Dictionary(all_tokens)

# filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=10, no_above=0.9)

# bag-of-words representation of the documents
corpus = [dictionary.doc2bow(text) for text in all_tokens]

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 567
# Number of documents: 2484

# %% [markdown]
# Similar size corpus as the scikit-learn implementation above

# %% [markdown]
# ### Iterate through different topic sizes

# %% [markdown]
# There are numerous coherence metrics, as outlined in the paper (http://svn.aksw.org/papers/2015/WSDM_Topic_Evaluation/public.pdf ) that the gensim implementation is based.

# %%
def compute_coherence_values(corpus, dictionary, num_topics):
    """
    Returns coherence of LDA model based for a given number of topics
    
    Arguments:
        corpus: list, of bag-of-words representation of each document
        dictionary: gensim dictionary oboject of document tokens
        num_topics: int, number of topics to model
    Returns:
        coherence: Cv coherence measure of topic model
    """
    
    # Set training parameters
    chunksize = 2000
    passes = 20
    iterations = 400
    eval_every = None  
    
    # Make a index to word dictionary.
    temp = dictionary[0]  # This is only to "load" the dictionary.
    id2word = dictionary.id2token
    
    lda_model = gensim.models.LdaModel(corpus=corpus,
                                       id2word=id2word,
                                       chunksize=chunksize,
                                       alpha='auto',
                                       eta='auto',
                                       iterations=iterations,
                                       num_topics=num_topics,
                                       passes=passes,
                                       eval_every=eval_every
                                      )
    
    coherence_model_lda = CoherenceModel(model=lda_model, 
                                         texts=all_tokens, 
                                         dictionary=dictionary, 
                                         coherence='c_v')
    
    coherence = coherence_model_lda.get_coherence()
    #perplexity = lda_model.log_perplexity(corpus)  
    
    return coherence

# %%
# %%time

coherence_scores = []
#perplexity_scores = []
for NUM_TOPICS in range(3,20):
    coherence = compute_coherence_values(corpus, dictionary, NUM_TOPICS)
    coherence_scores.append(coherence)
    #perplexity_scores.append(perplexity)
# Out:
# CPU times: user 3min 13s, sys: 14.7 s, total: 3min 28s
# Wall time: 3min 29s

# %%
x = range(3, 20)
y = coherence_scores

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x, y)

plt.xlabel('num topics', fontsize=18)
plt.ylabel('coherence', fontsize=18)
plt.title('LDA coherence vs number of topics', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
plt.savefig('lda_coherence.png')

# %%
list(range(3,20))[np.argmax(coherence_scores)]
# Out:
# 6

# %% [markdown]
# #### Investigate 'optimal' topic number model

# %% [markdown]
# The maximum coherence value in the range searched appears to be 111. However, it seems like coherence will continue to increase with more topics. Additionally, 111 is already quite high. Instead, we'll pick an earlier max of ~17 topics as the 'right' number of topics.

# %%
# Set training parameters
num_topics = 6
chunksize = 2000
passes = 20
iterations = 400
eval_every = 5  

# Make a index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model = gensim.models.LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)

# %%
top_topics = model.top_topics(corpus) #, num_words=20)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# Average topic coherence: -3.2511.
# [([(0.074354865, 'I'),
#    (0.057329062, 'to'),
#    (0.037788127, 'the'),
#    (0.03683632, 'it'),
#    (0.025074601, 'a'),
#    (0.024906972, 'and'),
#    (0.020545155, 'for'),
#    (0.020050686, 'was'),
#    (0.019448137, 'that'),
#    (0.015428566, 'this'),
#    (0.014081465, 'my'),
#    (0.01282025, 'with'),
#    (0.012424045, 'had'),
#    (0.011826144, 'have'),
#    (0.01173096, 'so'),
#    (0.011394716, 'but'),
#    (0.01131378, 'not'),
#    (0.008352231, 'of'),
#    (0.008100174, 'on'),
#    (0.007634351, 'do')],
#   -1.9361724707599834),
#  ([(0.059931654, 'is'),
#    (0.058158133, 'the'),
#    (0.042068236, 'you'),
#    (0.032173768, 'to'),
#    (0.027243916, 'that'),
#    (0.026638215, 'it'),
#    (0.02516019, 'only'),
#    (0.024056233, 'and'),
#    (0.022813668, 'The'),
#    (0.020293163, 'on'),
#    (0.015177112, 'with'),
#    (0.013822271, 'apps'),
#    (0.0123174265, 'The_only'),
#    (0.012021822, 'in'),
#    (0.010827432, 'of'),
#    (0.0107967, 'can'),
#    (0.01073718, 'not'),
#    (0.010268963, 'get'),
#    (0.010248463, 'a'),
#    (0.01008851, 'Amazon')],
#   -2.0339691932007433),
#  ([(0.095332325, 'the'),
#    (0.04945581, 'of'),
#    (0.032939274, 'not'),
#    (0.027743826, 'a'),
#    (0.026840048, 'and'),
#    (0.024110144, 'for'),
#    (0.023132095, 'I'),
#    (0.022248145, 'are'),
#    (0.019794118, 'tablet'),
#    (0.018487286, 'on'),
#    (0.017389415, 'screen'),
#    (0.017384695, 'was'),
#    (0.015807718, 'this'),
#    (0.015581886, 'ads'),
#    (0.013005081, 'is'),
#    (0.010936766, 'too'),
#    (0.010158866, 'out_of'),
#    (0.009918236, 'tablet.'),
#    (0.009782098, 'than'),
#    (0.00947969, 'out')],
#   -3.0901245585087795),
#  ([(0.08044306, 'a'),
#    (0.034258485, 'the'),
#    (0.031572834, 'little'),
#    (0.03133354, 'my'),
#    (0.030196734, 'of'),
#    (0.02886341, 'It'),
#    (0.028617604, 'is'),
#    (0.027124248, 'to'),
#    (0.026728626, 'I'),
#    (0.026016591, 'and'),
#    (0.023737455, 'a_little'),
#    (0.021950435, 'but'),
#    (0.021775179, 'slow'),
#    (0.019817963, 'not'),
#    (0.018417114, 'bit'),
#    (0.017450022, 'at'),
#    (0.015121225, 'a_bit'),
#    (0.014892092, 'did'),
#    (0.014283464, "don't"),
#    (0.012556685, 'did_not')],
#   -3.78589468857279),
#  ([(0.061774433, 'is'),
#    (0.053631943, 'as'),
#    (0.051426757, 'not'),
#    (0.045828596, 'the'),
#    (0.032178972, 'to'),
#    (0.028654411, 'but'),
#    (0.028632708, 'for'),
#    (0.02398401, 'The'),
#    (0.023860758, 'a'),
#    (0.018858448, 'good'),
#    (0.015071978, 'very'),
#    (0.013427773, 'camera'),
#    (0.012500044, 'tablet'),
#    (0.011260769, "can't"),
#    (0.011038559, 'like'),
#    (0.010744372, 'quality'),
#    (0.01051193, 'no'),
#    (0.010492458, "It's"),
#    (0.0103877215, "isn't"),
#    (0.010364501, 'price')],
#   -3.885705653151118),
#  ([(0.04881134, 'it'),
#    (0.048382353, 'to'),
#    (0.047825523, 'not'),
#    (0.043602098, 'is'),
#    (0.03933456, 'and'),
#    (0.035029918, 'for'),
#    (0.031852026, 'have'),
#    (0.03053145, 'This'),
#    (0.02111195, 'but'),
#    (0.02033783, 'Not'),
#    (0.020144885, 'a'),
#    (0.019260038, 'does'),
#    (0.01558628, 'does_not'),
#    (0.015004089, 'at'),
#    (0.013458349, 'Bought'),
#    (0.012803885, 'google'),
#    (0.012164607, "doesn't"),
#    (0.011896413, 'apps'),
#    (0.011274968, 'up'),
#    (0.010874559, 'It')],
#   -4.774758875283451)]

# %%
topics = model.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# (0, '0.060*"is" + 0.058*"the" + 0.042*"you" + 0.032*"to" + 0.027*"that"')
# (1, '0.074*"I" + 0.057*"to" + 0.038*"the" + 0.037*"it" + 0.025*"a"')
# (2, '0.095*"the" + 0.049*"of" + 0.033*"not" + 0.028*"a" + 0.027*"and"')
# (3, '0.080*"a" + 0.034*"the" + 0.032*"little" + 0.031*"my" + 0.030*"of"')
# (4, '0.049*"it" + 0.048*"to" + 0.048*"not" + 0.044*"is" + 0.039*"and"')
# (5, '0.062*"is" + 0.054*"as" + 0.051*"not" + 0.046*"the" + 0.032*"to"')

# %%
# compute coherence score
coherence_model_lda = CoherenceModel(model=model, 
                                     texts=all_tokens, 
                                     dictionary=dictionary, 
                                     coherence='c_v')

coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

print('\nPerplexity: ', model.log_perplexity(corpus))
# Out:
# Coherence Score:  0.3910966073456023
#
# Perplexity:  -5.562664897187784

# %% [markdown]
# ### Visualize the topics

# %% [markdown]
# pyLDAvis (https://github.com/bmabey/pyLDAvis) is a helpful tool for visualizing topics (although it doesn’t play nicely with Jupyter lab https://github.com/jupyterlab/jupyterlab/issues/7959)

# %%
pyLDAvis.enable_notebook()
LDAvis_prepared = pyLDAvis.gensim_models.prepare(model, corpus, dictionary)
LDAvis_prepared
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.051082  0.067988       1        1  38.032143
# 0      0.076665  0.012734       2        1  23.749330
# 2      0.067257  0.110370       3        1  13.515420
# 5      0.183627 -0.090016       4        1  10.473588
# 3     -0.145827  0.105477       5        1   8.061564
# 4     -0.130641 -0.206553       6        1   6.167954, topic_info=              Term         Freq        Total Category  logprob  loglift
# 88               I   945.000000   945.000000  Default  30.0000  30.0000
# 34              is   811.000000   811.000000  Default  29.0000  29.0000
# 31               a   729.000000   729.000000  Default  28.0000  28.0000
# 15             the  1367.000000  1367.000000  Default  27.0000  27.0000
# 35             not   597.000000   597.000000  Default  26.0000  26.0000
# 8               to  1068.000000  1068.000000  Default  25.0000  25.0000
# 57              of   421.000000   421.000000  Default  24.0000  24.0000
# 71              as   222.000000   222.000000  Default  23.0000  23.0000
# 23             you   320.000000   320.000000  Default  22.0000  22.0000
# 13              it   717.000000   717.000000  Default  21.0000  21.0000
# 136           have   255.000000   255.000000  Default  20.0000  20.0000
# 25             for   519.000000   519.000000  Default  19.0000  19.0000
# 11             and   669.000000   669.000000  Default  18.0000  18.0000
# 137             my   262.000000   262.000000  Default  17.0000  17.0000
# 87            only   182.000000   182.000000  Default  16.0000  16.0000
# 55             but   356.000000   356.000000  Default  15.0000  15.0000
# 158         little    72.000000    72.000000  Default  14.0000  14.0000
rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1, 3, 6, 4, 5])

# %%
pyLDAvis.disable_notebook()

# %% [markdown]
# ## Hierarchical Dirichlet Process

# %%
hdp = gensim.models.HdpModel(corpus, dictionary)

# %%
topic_info = hdp.print_topics(num_topics=-1, num_words=10)
len(topic_info)
# Out:
# 0

# %%
len(hdp.get_topics())
# Out:
# 150

# %% [markdown]
# In theory, the HDP algorithm is supposed to be able to automatically determine the number of topics in the data, but this dataset might be too small for it to be useful. See https://radimrehurek.com/gensim/models/hdpmodel.html for more details.

# %% [markdown]
# ## CorEx

# %%
def extract_theme(keyword_string):
    keywords = keyword_string.split(", ")
    res = max(keywords, key = len)
    return(res)

# %%
tfidf_vectorizer = TfidfVectorizer(max_df = 1.0, 
                                   min_df = 5, 
                                   ngram_range = (1, 2)
                                  )

vectorizer_positive = tfidf_vectorizer.fit(X_positive)
tfidf_positive = vectorizer_positive.transform(X_positive)
vocab_positive = vectorizer_positive.get_feature_names_out()
print(len(vocab_positive))
# Out:
# 6310

# %%
vectorizer_neutral = tfidf_vectorizer.fit(X_neutral)
tfidf_neutral = vectorizer_neutral.transform(X_neutral)
vocab_neutral = vectorizer_neutral.get_feature_names_out()
print(len(vocab_neutral))
# Out:
# 3291

# %%
vectorizer_negative = tfidf_vectorizer.fit(X_negative)
tfidf_negative = vectorizer_negative.transform(X_negative)
vocab_negative = vectorizer_negative.get_feature_names_out()
print(len(vocab_negative))
# Out:
# 1716

# %% [markdown]
# ### Without anchor words

# %%
anchors = []
model = ct.Corex(n_hidden=25)
model = model.fit(tfidf_positive, words=vocab_positive)
plt.figure(figsize=(10,5))
plt.bar(range(model.tcs.shape[0]), model.tcs, color='#4e79a7', width=0.5)
plt.xlabel('Topic', fontsize=16)
plt.ylabel('Total Correlation (nats)', fontsize=16)
plt.show()

# %%
topic_labels=[]
for i, topic_ngrams in enumerate(model.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print(f"Topic #{i+1}: {', '.join(topic_ngrams)}")
    topic_labels.append([i+1,', '.join(topic_ngrams)])

keywords_df_positive = pd.DataFrame(topic_labels, columns=['topic_num','keywords'])
keywords_df_positive['label'] = keywords_df_positive['keywords'].apply(lambda x: pd.Series(extract_theme(x)))
keywords_df_positive=keywords_df_positive[keywords_df_positive['label']!=''].reset_index()
keywords_df_positive
# Out:
# Topic #1: loves, loves it, for my, she loves, she, my, bought this, this for, he, bought
# Topic #2: games, books, reading, web, movies, watch, playing, games and, watching, the web
# Topic #3: love them, these, them, they, they love, of these, these for, and they, love, gifts
# Topic #4: easy, easy to, to use, use, to, set up, very easy, set, to set, use and
# Topic #5: recommend, would, would recommend, highly, recommend this, highly recommend, recommend it, to anyone, definitely recommend, anyone
# Topic #6: battery life, battery, life, memory, sd, card, expandable, sd card, slot, storage
# Topic #7: friday, black friday, black, beat, on black, can beat, go wrong, wrong, can go, can
# Topic #8: does, does everything, everything, need, what, to do, it does, need it, the job, do
# Topic #9: happy with, happy, very happy, with, am, purchase, pleased, pleased with, very pleased, with my
# Topic #10: if you, if, you, prime, amazon prime, you have, you are, have amazon, prime member, an amazon
# Topic #11: no, so far, far, complaints, no complaints, problems, no problems, far so, so, so good
# Topic #12: friendly, user friendly, user, very user, friendly and, kid friendly, is user, and user, very kid, kid
# Topic #13: parental, parental controls, controls, the parental, parental control, controls are, great parental, good parental, control, has parental
# Topic #14: my expectations, expectations, exceeded, exceeded my, has exceeded, expectations and, tablet exceeded, exceeds, met, then some
# Topic #15: starter, starter tablet, great starter, good starter, for starter, starter for
# Topic #16:
# Topic #17: quad, quad core, core
# Topic #18:
# Topic #19:
# Topic #20:
# Topic #21:
# Topic #22:
# Topic #23:
# Topic #24:
# Topic #25: reasonably priced, reasonably
#     index  topic_num  \
# 0       0          1
# 1       1          2
# 2       2          3
# 3       3          4
# 4       4          5
# 5       5          6
# 6       6          7
# 7       7          8
# 8       8          9
# 9       9         10
# 10     10         11
# 11     11         12
# 12     12         13
# 13     13         14
# 14     14         15
# 15     16         17
# 16     24         25
#
#                                                                                                                                      keywords  \
# 0                                                              loves, loves it, for my, she loves, she, my, bought this, this for, he, bought
# 1                                                            games, books, reading, web, movies, watch, playing, games and, watching, the web
# 2                                                         love them, these, them, they, they love, of these, these for, and they, love, gifts
# 3                                                                     easy, easy to, to use, use, to, set up, very easy, set, to set, use and
# 4          recommend, would, would recommend, highly, recommend this, highly recommend, recommend it, to anyone, definitely recommend, anyone
# 5                                                           battery life, battery, life, memory, sd, card, expandable, sd card, slot, storage
# 6                                                         friday, black friday, black, beat, on black, can beat, go wrong, wrong, can go, can
# 7                                                         does, does everything, everything, need, what, to do, it does, need it, the job, do
# 8                                             happy with, happy, very happy, with, am, purchase, pleased, pleased with, very pleased, with my
# 9                                               if you, if, you, prime, amazon prime, you have, you are, have amazon, prime member, an amazon
# 10                                                     no, so far, far, complaints, no complaints, problems, no problems, far so, so, so good
# 11                                     friendly, user friendly, user, very user, friendly and, kid friendly, is user, and user, very kid, kid
# 12  parental, parental controls, controls, the parental, parental control, controls are, great parental, good parental, control, has parental
# 13             my expectations, expectations, exceeded, exceeded my, has exceeded, expectations and, tablet exceeded, exceeds, met, then some
# 14                                                             starter, starter tablet, great starter, good starter, for starter, starter for
# 15                                                                                                                      quad, quad core, core
# 16                                                                                                              reasonably priced, reasonably
#
#                    label
# 0            bought this
# 1              games and
# 2              love them
# 3              very easy
# 4   definitely recommend
# 5           battery life
# 6           black friday
# 7        does everything
# 8           pleased with
# 9           amazon prime
# 10         no complaints
# 11         user friendly
# 12     parental controls
# 13      expectations and
# 14        starter tablet
# 15             quad core
# 16     reasonably priced

# %%
anchor_df = data_sample_positive.copy().reset_index()
new_boolean = model.transform(tfidf_positive)[:,list(keywords_df_positive.topic_num-1)]
labeled_df_positive = pd.DataFrame(columns=['product','year','year_str','review','sentiment','label_num','label'])

for idx_row,row in enumerate(new_boolean):
    for idx_col,col in enumerate(row):
        if col:
            labeled_df_positive.loc[len(labeled_df_positive.index)] = [anchor_df['product'][idx_row],anchor_df['year'][idx_row],str(anchor_df['year'][idx_row]),anchor_df['review'][idx_row],
                                                     anchor_df['predef_sentiment'][idx_row],keywords_df_positive['topic_num'][idx_col],keywords_df_positive['label'][idx_col]]

labeled_df_positive
# Out:
#          product  year year_str  \
# 0     B018Y229OU  2016     2016
# 1     B018Y229OU  2016     2016
# 2     B018Y229OU  2016     2016
# 3     B018Y229OU  2016     2016
# 4     B018Y229OU  2016     2016
# ...          ...   ...      ...
# 9432  B018Y229OU  2017     2017
# 9433  B018Y229OU  2017     2017
# 9434  B018Y229OU  2017     2017
# 9435  B018Y229OU  2017     2017
# 9436  B018Y229OU  2017     2017
#
#                                                                          review  \
# 0     Good basic tablet for checking email , web browsing , and reading ebooks.
# 1                                         I would strongly recommend buying it.
# 2                        It's a great reader but also good for surfing the web.
# 3                        Easy to set up and use, plus the price was reasonable.
# 4                                                      I got this for my niece.
# ...                                                                         ...
# 9432                                                               He loves it.
# 9433              I have bought 3 of these tablets for my great grand children.
# 9434              I have bought 3 of these tablets for my great grand children.
# 9435                   Bought this for my four year old niece and she loves it.
# 9436                        Its exactly what I am wanted and the price was fair
#
#      sentiment  label_num                 label
# 0     positive          2             games and
# 1     positive          5  definitely recommend
# 2     positive          2             games and
# 3     positive          4             very easy
# 4     positive          1           bought this
# ...        ...        ...                   ...
# 9432  positive          1           bought this
# 9433  positive          1           bought this
# 9434  positive          3             love them
# 9435  positive          1           bought this
# 9436  positive          8       does everything
#
# [9437 rows x 7 columns]

# %%
anchors = []
model = ct.Corex(n_hidden=25)
model = model.fit(tfidf_neutral, words=vocab_neutral)
plt.figure(figsize=(10,5))
plt.bar(range(model.tcs.shape[0]), model.tcs, color='#4e79a7', width=0.5)
plt.xlabel('Topic', fontsize=16)
plt.ylabel('Total Correlation (nats)', fontsize=16)
plt.show()

# %%
topic_labels=[]
for i, topic_ngrams in enumerate(model.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print(f"Topic #{i+1}: {', '.join(topic_ngrams)}")
    topic_labels.append([i+1,', '.join(topic_ngrams)])

keywords_df_neutral = pd.DataFrame(topic_labels, columns=['topic_num','keywords'])
keywords_df_neutral['label'] = keywords_df_neutral['keywords'].apply(lambda x: pd.Series(extract_theme(x)))
keywords_df_neutral=keywords_df_neutral[keywords_df_neutral['label']!=''].reset_index()
keywords_df_neutral
# Out:
# Topic #1: for my, bought, old, my, year old, year, one for, bought this, for, gift
# Topic #2: watch, games, movies, play games, read, books, to watch, play, videos, watch movies
# Topic #3: friday, black friday, black, on black, sale, friday for, on sale, 35, this on, for 35
# Topic #4: card, sd, you pay, pay for, what you, get what, memory, sd card, pay, you get
# Topic #5: parental, easy, parental controls, controls, set, carry, easy to, small enough, easy for, to carry
# Topic #6: does, job, the job, does the, it does, does everything, everything, gets the, does what, job done
# Topic #7: beat, beat the, can beat, the price, price, cant beat, beat it, cant, price you, for the
# Topic #8: to replace, replace, replace my, kindle, original, original kindle, kindle fire, replacement, replacement for, as replacement
# Topic #9: returning, returning it, up returning, be returning, ended up, ended, will be
# Topic #10: problems, no problems, had any, problems with, haven had, any problems, complaints, any complaints, geek squad, squad
# Topic #11:
# Topic #12:
# Topic #13:
# Topic #14:
# Topic #15: leave my, alone, leave, would leave
# Topic #16:
# Topic #17:
# Topic #18:
# Topic #19:
# Topic #20:
# Topic #21:
# Topic #22:
# Topic #23:
# Topic #24:
# Topic #25:
#     index  topic_num  \
# 0       0          1
# 1       1          2
# 2       2          3
# 3       3          4
# 4       4          5
# 5       5          6
# 6       6          7
# 7       7          8
# 8       8          9
# 9       9         10
# 10     14         15
#
#                                                                                                                          keywords  \
# 0                                                        for my, bought, old, my, year old, year, one for, bought this, for, gift
# 1                                             watch, games, movies, play games, read, books, to watch, play, videos, watch movies
# 2                                           friday, black friday, black, on black, sale, friday for, on sale, 35, this on, for 35
# 3                                                   card, sd, you pay, pay for, what you, get what, memory, sd card, pay, you get
# 4                              parental, easy, parental controls, controls, set, carry, easy to, small enough, easy for, to carry
# 5                               does, job, the job, does the, it does, does everything, everything, gets the, does what, job done
# 6                                        beat, beat the, can beat, the price, price, cant beat, beat it, cant, price you, for the
# 7   to replace, replace, replace my, kindle, original, original kindle, kindle fire, replacement, replacement for, as replacement
# 8                                                   returning, returning it, up returning, be returning, ended up, ended, will be
# 9           problems, no problems, had any, problems with, haven had, any problems, complaints, any complaints, geek squad, squad
# 10                                                                                            leave my, alone, leave, would leave
#
#                 label
# 0         bought this
# 1        watch movies
# 2        black friday
# 3            what you
# 4   parental controls
# 5     does everything
# 6           the price
# 7     original kindle
# 8        returning it
# 9      any complaints
# 10        would leave

# %%
anchor_df = data_sample_neutral.copy().reset_index()
new_boolean = model.transform(tfidf_neutral)[:,list(keywords_df_neutral.topic_num-1)]
labeled_df_neutral = pd.DataFrame(columns=['product','year','year_str','review','sentiment','label_num','label'])

for idx_row,row in enumerate(new_boolean):
    for idx_col,col in enumerate(row):
        if col:
            labeled_df_neutral.loc[len(labeled_df_neutral.index)] = [anchor_df['product'][idx_row],anchor_df['year'][idx_row],str(anchor_df['year'][idx_row]),anchor_df['review'][idx_row],
                                                     anchor_df['predef_sentiment'][idx_row],keywords_df_neutral['topic_num'][idx_col],keywords_df_neutral['label'][idx_col]]

labeled_df_neutral
# Out:
#          product  year year_str  \
# 0     B018Y229OU  2016     2016
# 1     B018Y229OU  2016     2016
# 2     B018Y229OU  2016     2016
# 3     B018Y229OU  2015     2015
# 4     B018Y229OU  2015     2015
# ...          ...   ...      ...
# 3326  B018Y229OU  2017     2017
# 3327  B018Y229OU  2017     2017
# 3328  B018Y229OU  2017     2017
# 3329  B018Y229OU  2017     2017
# 3330  B018Y229OU  2017     2017
#
#                                                   review sentiment  label_num  \
# 0      She is able to play games and watch videos on it.   neutral          2
# 1                She does occasionally read with it too.   neutral          2
# 2                              Purchased for my toddler.   neutral          1
# 3                                   Hasn't opened it yet   neutral         10
# 4                  I got two of these for my young kids.   neutral          1
# ...                                                  ...       ...        ...
# 3326                              I use it to read only.   neutral          2
# 3327                      was bought to use with Kindle.   neutral          1
# 3328               Got it for my daughter to read books.   neutral          1
# 3329               Got it for my daughter to read books.   neutral          2
# 3330  I bought this tablet for my grandson in 4th grade.   neutral          1
#
#                label
# 0       watch movies
# 1       watch movies
# 2        bought this
# 3     any complaints
# 4        bought this
# ...              ...
# 3326    watch movies
# 3327     bought this
# 3328     bought this
# 3329    watch movies
# 3330     bought this
#
# [3331 rows x 7 columns]

# %%
anchors = []
model = ct.Corex(n_hidden=25)
model = model.fit(tfidf_negative, words=vocab_negative)
plt.figure(figsize=(10,5))
plt.bar(range(model.tcs.shape[0]), model.tcs, color='#4e79a7', width=0.5)
plt.xlabel('Topic', fontsize=16)
plt.ylabel('Total Correlation (nats)', fontsize=16)
plt.show()

# %%
topic_labels=[]
for i, topic_ngrams in enumerate(model.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print(f"Topic #{i+1}: {', '.join(topic_ngrams)}")
    topic_labels.append([i+1,', '.join(topic_ngrams)])

keywords_df_negative = pd.DataFrame(topic_labels, columns=['topic_num','keywords'])
keywords_df_negative['label'] = keywords_df_negative['keywords'].apply(lambda x: pd.Series(extract_theme(x)))
keywords_df_negative=keywords_df_negative[keywords_df_negative['label']!=''].reset_index()
keywords_df_negative
# Out:
# Topic #1: store, app store, amazon app, app, play store, google play, play, google, not available, available
# Topic #2: lock screen, ads, lock, the lock, pop up, pop, the ads, ads on, that pop, annoying
# Topic #3: price, better tablet, the price, especially for, find better, better, believe the, this price, believe, tablet for
# Topic #4: figure out, figure, out how, out, right out, box, how to, pixels, with dead, to figure
# Topic #5: camera, the camera, camera is, quality is, camera isn, quality, that great, great, you pay, the best
# Topic #6: is the, only, the only, only downside, downside, only drawback, drawback is, downside is, drawback, complaint is
# Topic #7: recommend, not recommend, to anyone, anyone, recommend this, wouldn recommend, recommend to, would not, wouldn
# Topic #8: battery life, life, battery, life is, the battery, short, long
# Topic #9: charging port, port, charging, stopped working, stopped, port is, working, within, the charging, month
# Topic #10: parental controls, controls, parental
# Topic #11: wi fi, wi, fi
# Topic #12: waste of, waste, of money, money
# Topic #13:
# Topic #14:
# Topic #15:
# Topic #16:
# Topic #17: tech, tech savvy, savvy, she is
# Topic #18:
# Topic #19:
# Topic #20:
# Topic #21:
# Topic #22:
# Topic #23:
# Topic #24: processor, little slow, the processor, slow, little, slow at, at times, times
# Topic #25: replace, to replace, old, replace my, old and, years old, black friday, friday, years, black
#     index  topic_num  \
# 0       0          1
# 1       1          2
# 2       2          3
# 3       3          4
# 4       4          5
# 5       5          6
# 6       6          7
# 7       7          8
# 8       8          9
# 9       9         10
# 10     10         11
# 11     11         12
# 12     16         17
# 13     23         24
# 14     24         25
#
#                                                                                                               keywords  \
# 0                   store, app store, amazon app, app, play store, google play, play, google, not available, available
# 1                                   lock screen, ads, lock, the lock, pop up, pop, the ads, ads on, that pop, annoying
# 2   price, better tablet, the price, especially for, find better, better, believe the, this price, believe, tablet for
# 3                               figure out, figure, out how, out, right out, box, how to, pixels, with dead, to figure
# 4                 camera, the camera, camera is, quality is, camera isn, quality, that great, great, you pay, the best
# 5     is the, only, the only, only downside, downside, only drawback, drawback is, downside is, drawback, complaint is
# 6       recommend, not recommend, to anyone, anyone, recommend this, wouldn recommend, recommend to, would not, wouldn
# 7                                                       battery life, life, battery, life is, the battery, short, long
# 8               charging port, port, charging, stopped working, stopped, port is, working, within, the charging, month
# 9                                                                                parental controls, controls, parental
# 10                                                                                                       wi fi, wi, fi
# 11                                                                                    waste of, waste, of money, money
# 12                                                                                     tech, tech savvy, savvy, she is
# 13                                       processor, little slow, the processor, slow, little, slow at, at times, times
# 14                        replace, to replace, old, replace my, old and, years old, black friday, friday, years, black
#
#                 label
# 0       not available
# 1         lock screen
# 2      especially for
# 3          figure out
# 4          the camera
# 5       only downside
# 6    wouldn recommend
# 7        battery life
# 8     stopped working
# 9   parental controls
# 10              wi fi
# 11           waste of
# 12         tech savvy
# 13      the processor
# 14       black friday

# %%
anchor_df = data_sample_negative.copy().reset_index()
new_boolean = model.transform(tfidf_negative)[:,list(keywords_df_negative.topic_num-1)]
labeled_df_negative = pd.DataFrame(columns=['product','year','year_str','review','sentiment','label_num','label'])

for idx_row,row in enumerate(new_boolean):
    for idx_col,col in enumerate(row):
        if col:
            labeled_df_negative.loc[len(labeled_df_negative.index)] = [anchor_df['product'][idx_row],anchor_df['year'][idx_row],str(anchor_df['year'][idx_row]),anchor_df['review'][idx_row],
                                                     anchor_df['predef_sentiment'][idx_row],keywords_df_negative['topic_num'][idx_col],keywords_df_negative['label'][idx_col]]

labeled_df_negative
# Out:
#         product  year year_str  \
# 0    B018Y229OU  2016     2016
# 1    B018Y229OU  2016     2016
# 2    B018Y229OU  2016     2016
# 3    B018Y229OU  2016     2016
# 4    B018Y229OU  2016     2016
# 5    B018Y229OU  2016     2016
# 6    B018Y229OU  2016     2016
# 7    B018Y229OU  2016     2016
# 8    B018Y229OU  2016     2016
# 9    B018Y229OU  2016     2016
# 10   B018Y229OU  2016     2016
# 11   B018Y229OU  2016     2016
# 12   B018Y229OU  2016     2016
# 13   B018Y229OU  2017     2017
# 14   B018Y229OU  2016     2016
# 15   B018Y229OU  2016     2016
# 16   B018Y229OU  2016     2016
# 17   B018Y229OU  2016     2016
# 18   B018Y229OU  2016     2016
# 19   B018Y229OU  2016     2016
# 20   B018Y229OU  2016     2016
# 21   B018Y229OU  2017     2017
# 22   B018Y229OU  2017     2017
# 23   B018Y229OU  2015     2015
# 24   B018Y229OU  2015     2015
# 25   B018Y229OU  2017     2017
# 26   B018Y229OU  2017     2017
# 27   B018Y229OU  2015     2015
# 28   B018Y229OU  2015     2015
# 29   B018Y229OU  2015     2015
# 30   B018Y229OU  2017     2017
# 31   B018Y229OU  2017     2017
# 32   B018Y229OU  2017     2017
# 33   B018Y229OU  2017     2017
# 34   B018Y229OU  2017     2017
# 35   B018Y229OU  2015     2015
# 36   B018Y229OU  2015     2015
# 37   B018Y229OU  2016     2016
# 38   B018Y229OU  2016     2016
# 39   B018Y229OU  2016     2016
# 40   B018Y229OU  2016     2016
# 41   B018Y229OU  2016     2016
# 42   B018Y229OU  2016     2016
# 43   B018Y229OU  2016     2016
# 44   B018Y229OU  2016     2016
# 45   B018Y229OU  2016     2016
# 46   B018Y229OU  2016     2016
# 47   B018Y229OU  2016     2016
# 48   B018Y229OU  2016     2016
# 49   B018Y229OU  2016     2016
# 50   B018Y229OU  2016     2016
# 10                                                                                                                                                                                                                                              The battery dies really fast though.
# 11                                                                                                                                                                                                                                          the only thing this needs is more space.
# 12                                                                                                                                                                                                                           Only downside is the connection speed is somewhat slow.
# 13                                                                                                                                                                                                                                                Stopped working after only a year.
# 14                                                                                                                                                                                                                                    for 50 bucks you will not get a better tablet.
# 15                                                                                                                                                                                                     bought two and 1 week later one will not connect to wifi will have to return.
# 16                                                                                                                                                                                                  Only issue I have with it is the advertisements that pop up when you turn it on.
# 17                                                                                                                                                                                                                          But don't male me gp allthe way there and waste my time.
# 18                                                                                                                                                                                                                                                  It wouldn't connect to internet.
# 19                                                                               There are only 2 things that I wish this Kindle had: there is no sleep/wake function and it doesn't have the micro hdmi port to connect it to my TV, but again, for the price it's a great product.
# 20                                                                                                                                                                                                       My only complaint is that even with the 32g scan card, it fills up quickly.
# 21                                                                                                                                                                                  First, I couldn't believe the price; they were on sale for $35 but are normally still under $50.
# 22                                                                                                                                                                                                                                     The only negative is there was no blue tooth.
# 23                                                                                                                                                                                                    It is slow, not at all user friendly, and the advertising is so very annoying.
# 24                                                                                                                                                                  I purchased two of these tablets to replace all the other brands that stopped working within a two month period.
# 25                                                                                                                                                                                                                                      Worst thing is the charger and battery life.
# 26                                                                                                                                                                                                                                      Worst thing is the charger and battery life.
# 27                                                                                                                                                                                                                                  Missing Google Play Store and screen is only ok.
# 28                                                                                                                                                                                 Several of the most popular apps (Instagram, You Tube, etc.) are NOT compatible with this device.
# 29                                                                                                                                                                                                     They are 5, 6, and seven years old and I have to tell Them to put these down.
# 30                                                                                                                                                                                                                      The only negative is that the charging port is very fragile.
# 31                                                                                                                                                                                                                      The only negative is that the charging port is very fragile.
# 32                                                                                                                                             Took it home and when I charged it up, the back of the tablet became very hot to the touch and the battery life reduced dramatically.
# 33                                                                                                                                                               Not a fan of Amazon's Fire OS and wish it had Android but most of the apps are available so it's not a major issue.
# 34                                                                                                                                                                                                                                             I will never recommend this to anyone
# 35                                                                                                                                        It is not a truly "open" android system, as it's locked down in some ways by Amazon (i.e. you cannot easily access the google play store).
# 36                                                                                                                                                                                                                  The only downside is we can't figure out how to get Google apps.
# 37                                                                                                                                                                     AND IT WON'T CONNECT TO ANY WIFI THAT NEEDS A PASSCODE OR PASSWORD BECAUSE IT HAS TO HAVE CORRECT TIME!!!!!!!
# 38                                                                                                                                                                                                                                                            The camera is terrible
# 39                                                                                                                                                Even though it looks like Android, the Play Store is not available and not all of the basic apps are included in the Kindle Store.
# 40                                                                                                                                    I've noticed that internet connection will not function if there is not enough room in memory, so delete some apps if you cannot access wi-fi.
# 41                                                                                                                                                                                                                                  I couldn't even get it set up for him to use it.
# 42                                                                                                                                                                                                                                            This tablet would not connect to wifi.
# 43                                                                                                                                                                                        and it is very slow and that ability is not a good working tablet I would not recommend it
# 44                                                                                                                                                                                                                                        but my only complaint is the battery life.
# 45                                                                                                                                                                                                                                        but my only complaint is the battery life.
# 46                                                                                                                                                                                                                                                Charging port is very poorly built
# 85                                                                                                                                         You also can't save anything of merit like books or magazines to a mini-SD card, thus making a purchase of one a waste of time and money.
# 86                                                                                                                                                                                                                                       You get what you pay for with this product.
# 87                                                                                                                                                                                                                                                  It simply can't replace my iPad.
# 88                                                                                                                                                                                                  Ads on lock screen is a bit of a let down but it functions like its supposed to.
# 89                                                                                                                                                                                                                                                    The battery life is very poor.
# 90                                                                                                                                                                                                                                The battery life is not as long as my 7" Fire HDX.
# 91                                                                                                                                  She is 3 so she will drop and be rough with the tablet seems sturdy enough and not expensive that it's going to break the bank if she damages it
# 92                                                                                                                                                                                                                        Only thing not happy about is the lack of under $10 cases.
# 93                                                                                                                                                                                                                 Bought this because my old Galaxy Tab 10 has become old and slow.
# 94                                                                                                                                                 Only reason it gets 4 stars versus 5 is the annoying ad on the lock screen (although I'm sure that's why the device is so cheap).
# 95                                                                                                                                                 Amazon has done a decent job in adding new software, but it's app store is nowhere near as robust as the Google and Apple stores.
# 96                                                                                                                                                                                                                                  the only thing missing is no google play store:(
# 97                                                                                                                                                                                              They are not powerful, they do not have a bright screen, and the battery life is ok.
# 98                                                                                                                                                                Lots of pre installed apps and the ads on the sleep screen are annoying but for around 50 bucks not a bad product.
# 99                                                                                                                              The OS is very different from a standard tablet OS - I couldn't get an app that I wanted from the Google Play Store - it just wouldn't work on this.
# 100                                                                                                                                                                                                 The only negative thing is that I still haven't figure out how to print from it.
# 101                                                                                                                                                                                                 The only negative thing is that I still haven't figure out how to print from it.
# 102                                                                                                              The charging port on mine seems to not be working well (have to push it up to connect properly), but the kids tend to just rip the power cord out without any care.
# 103                                                                                                              The charging port on mine seems to not be working well (have to push it up to connect properly), but the kids tend to just rip the power cord out without any care.
# 104                                                                                                                                                                                                               The only drawback is its inability to hold a charge for very long.
# 105                                                                                                                                                                                                                                            It was to complicated for him to use.
# 106                                                                                                                                                                                                                                   You shouldn't have to pay to remove bloatware.
# 107                                                                                                                                                                                                                                              Only downside with memory at 8gigs.
# 108                                                                                                                                                                                        The ONLY downside, won't connect over 5ghz (Wireless-N), stuck on the 2.5ghz connections.
# 109                                                                                                                                                                    My only complaint is the battery life is not (by a factor of (at least) 50) as good as on my KIndle e-reader.
# 110                                                                                                                                                                                      I was somewhat skeptical about getting this tablet, and especially for that low of a price.
# 111                                                                                                                                                                                                  The only thing I don't like is the power plug it sometimes don't want to charge
# 112                                                                                                                                                                                                                                         Battery life can't hold up to a 5yr old.
# 113                                                                                                                                                                   What I don't like is the constant ads that pop up because they want you to purchase whatever app you're using.
# 114                                                                                                                                                                                                                My only complaint is my old eyes struggle with the smaller print.
# ...
# 107  negative          6      only downside
# 108  negative         11              wi fi
# 109  negative          8       battery life
# 110  negative          3     especially for
# 111  negative          6      only downside
# 112  negative          8       battery life
# 113  negative          2        lock screen
# 114  negative          6      only downside
# 115  negative          9    stopped working
# 116  negative          2        lock screen
# 117  negative          6      only downside
# 118  negative          5         the camera
# 119  negative         11              wi fi
# 120  negative          8       battery life
# 121  negative          6      only downside
# 122  negative          8       battery life
# 123  negative          6      only downside
# 124  negative         25       black friday
# 125  negative         11              wi fi
# 126  negative         12           waste of
# 127  negative         12           waste of
# 128  negative         12           waste of
# 129  negative          8       battery life
# 130  negative         17         tech savvy
# 131  negative          3     especially for
# 132  negative          3     especially for
# 133  negative         25       black friday
# 134  negative          1      not available
# 135  negative          1      not available
# 136  negative          6      only downside
# 137  negative          5         the camera
# 138  negative         11              wi fi
# 139  negative          8       battery life
# 140  negative         11              wi fi
# 141  negative          6      only downside
# 142  negative          1      not available
# 143  negative         25       black friday
# 144  negative         17         tech savvy
# 145  negative          4         figure out
# 146  negative          1      not available
# 147  negative          8       battery life
# 148  negative          6      only downside
# 149  negative         24      the processor
# 150  negative          9    stopped working
# 151  negative          6      only downside
# 152  negative          8       battery life
# 153  negative         11              wi fi
# 154  negative          3     especially for
# 155  negative          6      only downside
# 156  negative          6      only downside
# 157  negative          3     especially for
# 158  negative         11              wi fi
# 159  negative         12           waste of
# 160  negative         25       black friday
# 161  negative          6      only downside
# 162  negative          2        lock screen
# 163  negative          6      only downside
# 164  negative         12           waste of
# 165  negative         17         tech savvy
# 166  negative          3     especially for
# 167  negative          3     especially for
# 168  negative          9    stopped working
# 169  negative          3     especially for
# 170  negative          5         the camera
# 171  negative          6      only downside
# 172  negative         25       black friday
# 173  negative         11              wi fi
# 174  negative          2        lock screen
# 175  negative          1      not available
# 176  negative         11              wi fi
# 177  negative          2        lock screen
# 178  negative          1      not available
# 179  negative          2        lock screen
# 180  negative         10  parental controls
# 181  negative          8       battery life
# 182  negative         25       black friday
# 183  negative          7   wouldn recommend
# 184  negative          6      only downside
# 185  negative          1      not available
# 186  negative         10  parental controls
# 187  negative          1      not available
# 188  negative          8       battery life
# 189  negative          7   wouldn recommend
# 190  negative          4         figure out
# 191  negative          6      only downside
# 192  negative          5         the camera
# 193  negative          7   wouldn recommend
# 194  negative         25       black friday
# 195  negative          9    stopped working
# 196  negative          1      not available
# 197  negative          5         the camera
# 198  negative         17         tech savvy
# 199  negative         24      the processor
# 200  negative          3     especially for
# 201  negative          9    stopped working
# 202  negative          6      only downside
# 203  negative         25       black friday
# 204  negative          7   wouldn recommend
# 205  negative          2        lock screen
# 206  negative          7   wouldn recommend
# 207  negative          2        lock screen
# 208  negative          2        lock screen
# 209  negative          2        lock screen
# 210  negative          8       battery life
# 211  negative          1      not available
# 212  negative          6      only downside
# 213  negative          1      not available
# 214  negative          2        lock screen
# 215  negative          2        lock screen
# 216  negative          8       battery life
# 217  negative          8       battery life
# 218  negative          3     especially for
# 219  negative          1      not available
# 220  negative         11              wi fi
# 221  negative          6      only downside
# 222  negative          6      only downside
# 223  negative          1      not available
# 224  negative          6      only downside
# 225  negative          3     especially for
# 226  negative          7   wouldn recommend
# 227  negative          6      only downside
# 228  negative         17         tech savvy
# 229  negative          9    stopped working
# 230  negative          6      only downside
# 231  negative          1      not available
# 232  negative          1      not available
# 233  negative          1      not available
# 234  negative          1      not available
# 235  negative          1      not available
# 236  negative          7   wouldn recommend
# 237  negative          9    stopped working
# 238  negative          6      only downside
# 239  negative          7   wouldn recommend
# 240  negative          6      only downside
# 241  negative          6      only downside
# 242  negative         11              wi fi
# 243  negative         17         tech savvy
# 244  negative          8       battery life
# 245  negative          6      only downside
# 246  negative          2        lock screen
# 247  negative         11              wi fi
# 248  negative          6      only downside
# 249  negative          3     especially for
# 250  negative          4         figure out
# 251  negative         12           waste of
# 252  negative         11              wi fi
# 253  negative         12           waste of
# 254  negative          3     especially for
# 255  negative         17         tech savvy
# 256  negative          3     especially for
# 257  negative          1      not available
# 258  negative          3     especially for
# 259  negative         17         tech savvy
# 260  negative          8       battery life
# 261  negative          3     especially for
# 262  negative         11              wi fi
# 263  negative          1      not available
# 264  negative         11              wi fi
# 265  negative          8       battery life
# 266  negative          2        lock screen
# 267  negative          8       battery life
# 268  negative          5         the camera
# 269  negative          6      only downside
# 270  negative         24      the processor
# 271  negative         25       black friday
# 272  negative          5         the camera
# 273  negative          2        lock screen
# 274  negative          2        lock screen
# 275  negative          1      not available
# 276  negative          7   wouldn recommend
# 277  negative          7   wouldn recommend
# 278  negative         11              wi fi
# 279  negative          3     especially for
# 280  negative          2        lock screen
# 281  negative          1      not available
# 282  negative         12           waste of
# 283  negative          2        lock screen
# 284  negative         10  parental controls
# 285  negative          5         the camera
# 286  negative         12           waste of
# 287  negative          6      only downside
# 288  negative          2        lock screen
# 289  negative         12           waste of
# 290  negative          2        lock screen
# 291  negative          5         the camera
# 292  negative         17         tech savvy
# 293  negative          3     especially for
# 294  negative          8       battery life
# 295  negative          8       battery life
# 296  negative         17         tech savvy
# 297  negative          7   wouldn recommend
# 298  negative          4         figure out
# 299  negative          7   wouldn recommend
# 300  negative         10  parental controls
# 301  negative          9    stopped working
# 302  negative          5         the camera
# 303  negative          5         the camera
# 304  negative          2        lock screen
# 305  negative          6      only downside
# 306  negative         11              wi fi
# 307  negative          7   wouldn recommend
# 308  negative          6      only downside
# 309  negative          1      not available
# 310  negative          3     especially for
# 311  negative          5         the camera
# 312  negative         24      the processor
# 313  negative          6      only downside
# 314  negative         11              wi fi
# 315  negative         24      the processor
# 316  negative          8       battery life
# 317  negative          1      not available
# 318  negative         24      the processor
# 319  negative         11              wi fi
# 320  negative          7   wouldn recommend
# 321  negative          7   wouldn recommend
# 322  negative         17         tech savvy
# 323  negative          8       battery life
# 324  negative          5         the camera
# 325  negative         11              wi fi
# 326  negative          1      not available
# 327  negative          7   wouldn recommend
# 328  negative          9    stopped working
# 329  negative          6      only downside
# 330  negative         11              wi fi
# 331  negative          9    stopped working
# 332  negative          8       battery life
# 333  negative          8       battery life
# 334  negative          5         the camera
# 335  negative          6      only downside
# 336  negative          8       battery life
# 337  negative          8       battery life
# 338  negative          3     especially for
# 339  negative          4         figure out
# 340  negative          6      only downside
# 341  negative         10  parental controls
# 342  negative          3     especially for
# 343  negative          4         figure out
# 344  negative          4         figure out
# 345  negative          6      only downside
# 346  negative          4         figure out
# 347  negative         11              wi fi
# 348  negative          4         figure out
# 349  negative          1      not available
# 350  negative          2        lock screen
# 351  negative          6      only downside
# 352  negative          1      not available
# 353  negative          1      not available
# 354  negative          6      only downside
# 355  negative         17         tech savvy
# 356  negative          6      only downside
# 357  negative          3     especially for
# 358  negative          6      only downside
# 359  negative          2        lock screen
# 360  negative          4         figure out
# 361  negative          6      only downside
# 362  negative         12           waste of
# 363  negative         12           waste of
# 364  negative          2        lock screen
# 365  negative          5         the camera
# 366  negative          1      not available
# 367  negative          2        lock screen
# 368  negative         24      the processor
# 369  negative          2        lock screen
# 370  negative         10  parental controls
# 371  negative          6      only downside
# 372  negative          3     especially for
# 373  negative          5         the camera
# 374  negative         10  parental controls
# 375  negative          5         the camera
# 376  negative          3     especially for
# 377  negative         11              wi fi
# 378  negative          3     especially for
# 379  negative          5         the camera
# 380  negative         12           waste of
# 381  negative         25       black friday
# 382  negative         17         tech savvy
# 383  negative          1      not available
# 384  negative          5         the camera
# 385  negative          1      not available
# 386  negative          4         figure out
# 387  negative         25       black friday
# 388  negative          2        lock screen
# 389  negative          2        lock screen
# 390  negative          6      only downside
# 391  negative          6      only downside
# 392  negative          9    stopped working
# 393  negative          1      not available
# 394  negative          2        lock screen
# 395  negative          4         figure out
# 396  negative          3     especially for
# 397  negative         17         tech savvy
# 398  negative          3     especially for
# 399  negative         24      the processor
# 400  negative         11              wi fi
# 401  negative          7   wouldn recommend
# 402  negative          6      only downside
# 403  negative         17         tech savvy
# 404  negative          3     especially for
# 405  negative         17         tech savvy
# 406  negative         10  parental controls
# 407  negative          5         the camera
# 408  negative         17         tech savvy
# 409  negative          8       battery life
# 410  negative          2        lock screen
# 411  negative         11              wi fi
# 412  negative          6      only downside
# 413  negative          1      not available
# 414  negative          1      not available
# 415  negative          6      only downside
# 416  negative          4         figure out
# 417  negative          1      not available
# 418  negative         12           waste of
# 419  negative          7   wouldn recommend
# 420  negative         25       black friday
# 421  negative          5         the camera
# 422  negative          6      only downside
# 423  negative          2        lock screen
# 424  negative          2        lock screen
# 425  negative         11              wi fi
# 426  negative         25       black friday
# 427  negative          3     especially for
# 428  negative          8       battery life
# 429  negative          3     especially for
# 430  negative          2        lock screen
# 431  negative         17         tech savvy
# 432  negative          5         the camera
# 433  negative          4         figure out
# 434  negative          7   wouldn recommend
# 435  negative         10  parental controls
# 436  negative          1      not available
# 437  negative          2        lock screen
# 438  negative          2        lock screen
# 439  negative          7   wouldn recommend
# 440  negative          5         the camera
# 441  negative          8       battery life
# 442  negative          2        lock screen
# 443  negative          7   wouldn recommend
# 444  negative          9    stopped working
# 445  negative         17         tech savvy
# 446  negative          3     especially for
# 447  negative          5         the camera
# 448  negative          5         the camera
# 449  negative          6      only downside
# 450  negative          7   wouldn recommend
# 451  negative          2        lock screen
# 452  negative          5         the camera
# 453  negative         11              wi fi

# %%
labels_df = pd.concat([labeled_df_positive,labeled_df_neutral,labeled_df_negative])
labels_df
# Out:
#         product  year year_str  \
# 0    B018Y229OU  2016     2016
# 1    B018Y229OU  2016     2016
# 2    B018Y229OU  2016     2016
# 3    B018Y229OU  2016     2016
# 4    B018Y229OU  2016     2016
# ..          ...   ...      ...
# 449  B018Y229OU  2017     2017
# 450  B018Y229OU  2017     2017
# 451  B018Y229OU  2017     2017
# 452  B018Y229OU  2017     2017
# 453  B018Y229OU  2017     2017
#
#                                                                                                                                                                                    review  \
# 0                                                                                                               Good basic tablet for checking email , web browsing , and reading ebooks.
# 1                                                                                                                                                   I would strongly recommend buying it.
# 2                                                                                                                                  It's a great reader but also good for surfing the web.
# 3                                                                                                                                  Easy to set up and use, plus the price was reasonable.
# 4                                                                                                                                                                I got this for my niece.
# ..                                                                                                                                                                                    ...
# 449                                                                                                        Only thing is the charger doesnt stay in the port and battery doesnt last long
# 450                                                                                                                    Love my watch bumper, but the tablet is so slow wouldn't recommend
# 451                                                                                                                                                                         Too many ads.
# 452                                                                                                                                                       The camera quality is horrible.
# 453  Only complaint is, you have to reconnect it to WiFi again whenever you turn it off and back on - and sometimes it won't connect to certain ones - possibly due to security settings?
#
#     sentiment  label_num                 label
# 0    positive          2             games and
# 1    positive          5  definitely recommend
# 2    positive          2             games and
# 3    positive          4             very easy
# 4    positive          1           bought this
# ..        ...        ...                   ...
# 449  negative          6         only downside
# 450  negative          7      wouldn recommend
# 451  negative          2           lock screen
# 452  negative          5            the camera
# 453  negative         11                 wi fi
#
# [13222 rows x 7 columns]

# %%
with open(f'Reviews_{product_asin}_label_predef.pkl', 'wb') as f:
    pickle.dump(labels_df, f)
labels_df
# Out:
#         product  year year_str  \
# 0    B018Y229OU  2016     2016
# 1    B018Y229OU  2016     2016
# 2    B018Y229OU  2016     2016
# 3    B018Y229OU  2016     2016
# 4    B018Y229OU  2016     2016
# ..          ...   ...      ...
# 449  B018Y229OU  2017     2017
# 450  B018Y229OU  2017     2017
# 451  B018Y229OU  2017     2017
# 452  B018Y229OU  2017     2017
# 453  B018Y229OU  2017     2017
#
#                                                                                                                                                                                    review  \
# 0                                                                                                               Good basic tablet for checking email , web browsing , and reading ebooks.
# 1                                                                                                                                                   I would strongly recommend buying it.
# 2                                                                                                                                  It's a great reader but also good for surfing the web.
# 3                                                                                                                                  Easy to set up and use, plus the price was reasonable.
# 4                                                                                                                                                                I got this for my niece.
# ..                                                                                                                                                                                    ...
# 449                                                                                                        Only thing is the charger doesnt stay in the port and battery doesnt last long
# 450                                                                                                                    Love my watch bumper, but the tablet is so slow wouldn't recommend
# 451                                                                                                                                                                         Too many ads.
# 452                                                                                                                                                       The camera quality is horrible.
# 453  Only complaint is, you have to reconnect it to WiFi again whenever you turn it off and back on - and sometimes it won't connect to certain ones - possibly due to security settings?
#
#     sentiment  label_num                 label
# 0    positive          2             games and
# 1    positive          5  definitely recommend
# 2    positive          2             games and
# 3    positive          4             very easy
# 4    positive          1           bought this
# ..        ...        ...                   ...
# 449  negative          6         only downside
# 450  negative          7      wouldn recommend
# 451  negative          2           lock screen
# 452  negative          5            the camera
# 453  negative         11                 wi fi
#
# [13222 rows x 7 columns]
